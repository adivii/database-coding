# %%
import json
import random
import string
import os
import pandas as pd
import re

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")
nltk.download("wordnet")
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\adiha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\adiha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\adiha\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# ## Creating Question Pattern

# %%
class Modeling_rule_based:
    # get product name manual
    ## filter product name, perlu di regex lagi
    def get_product(self, p):
        p = p[p.find('*'):len(p)]
        p = p[:p.find('\n')]
        p = p.lower()
        p = re.sub("[^0-9a-z]+", " ", p)

        replacements = {
            '(?<=\s|[0-9])+(g|gr)+(?=\s|\.|$)' : 'gram',
            '(?<=\s|[0-9])+mg+(?=\s|\.|$)' : 'miligram',
            '(?<=\s|[0-9])+ml+(?=\s|\.|$)' : 'mililiter',
            '(?<=\s|[0-9])+l+(?=\s|\.|$)' : 'liter'
        }

        for key, value in replacements.items():
            p = re.sub(key, value, p)

        # p = re.sub("gr",  "gram", p)
        # p = re.sub("ml", "mililiter", p)
        return p

    # create question manual
    ## keyword berdasarkan huruf terbanyak yang muncul
    def create_questions(self, c, q):
        list_q = []
        if c == "product_info":
            q1 = q 
            q2 = "kegunaan " + q
            q3 = "penggunaan " + q
            q4 = "cara pakai " + q
            q5 = "bagaimana menggunakan " + q
            q6 = "cara menggunakan " + q
            q7 = "cara penyimpanan " + q
            q8 = "bagaimana menyimpan " + q
            q9 = "cara menyimpan " + q
            q10 = "apa itu " + q
            q11 = "harga " + q
            q12 = "berapa biaya " + q
            list_q = [q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12]
        elif c == "treatment_info":
            q1 = q
            q2 = "apa itu " + q
            q3 = "manfaat " + q
            q4 = "manfaat menggunakan" + q
            q5 = "keuntungan menggunakan " + q
            q6 = "prosedur " + q
            q7 = "bagaimana pengerjaan " + q
            q8 = "bagaimana cara kerja " + q
            q9 = "durasi " + q
            q10 = "berapa lama " + q
            q11 = "harga " + q
            q12 = "berapa biaya " + q
            list_q = [q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12]
        
        return list_q

# %%
model = Modeling_rule_based()

# %%
os.chdir("E:\\Documents\\Coding\\Notebooks\\Chatbot\\apotek")
print(os.getcwd())
# Out:
# E:\Documents\Coding\Notebooks\Chatbot\apotek

# %%
df = pd.read_csv("dataset_transformation - dataset_transformation.csv")

# %%
df.head()
# Out:
#                       Content ID  \
# 0             conversation_start
# 1             fallback_too_short
# 2           fallback_too_complex
# 3  fallback_too_complex_simplify
# 4    handover_livechat_agent_end
#
#                                             Answer 1  \
# 0  Hi. Welcome to ERHA, \n\nTerima kasih telah me...
# 1  Keyword yang dimasukkan tidak Elsa mengerti, s...
# 2  Keyword yang dimasukkan tidak Elsa mengerti, s...
# 3  Keyword yang dimasukkan tidak Elsa mengerti, s...
# 4                Terima kasih sudah menghubungi ERHA
#
#                                     answer_tokenized  Status question  \
# 0  ['hi', 'welcome', 'to', 'erha', 'terima', 'kas...             True
# 1  ['keyword', 'elsa', 'erti', 'silah', 'ketik', ...             True
# 2  ['keyword', 'elsa', 'erti', 'silah', 'ketik', ...             True
# 3  ['keyword', 'elsa', 'erti', 'silah', 'ketik', ...             True
# 4              ['terima', 'kasih', 'hubung', 'erha']             True
#
#   Next Event                     Next Data Version ID Condition 1 Operator  \
# 0       goto  conversation_start:user_info        NaN                  NaN
# 1        NaN                           NaN        NaN             INCLUDES
# 2        NaN                           NaN        NaN             INCLUDES
# 3        NaN                           NaN        NaN             INCLUDES
# 4        NaN                           NaN        NaN                  NaN
#
#   Condition 1 Property Condition 1 Value
# 0                  NaN               NaN
# 1               source          whatsapp
# 2               source          whatsapp
# 3               source          whatsapp
# 4                  NaN               NaN

# %%
df2 = df[df['Content ID'].isin(['product_info','treatment_info'])][['Content ID', 'Version ID', 'Answer 1']]
df2
# Out:
#          Content ID                                         Version ID  \
# 50     product_info                                              erha4
# 51     product_info                                              erha5
# 52     product_info                                              erha6
# 54     product_info                                              erha7
# 55     product_info                                              erha9
# ..              ...                                                ...
# 546  treatment_info                   BLACK CARBON SKINPROVEMENT LASER
# 547    product_info                                   Acne Guard Cream
# 548    product_info                        HISERHA ENERGY BRIGHT CREAM
# 549    product_info  Urban Skin Defense Multi Benefit Refreshing Spray
# 550    product_info            ERHA Skinsitive DF Ultracalm Face Serum
#
#                                               Answer 1
# 50   Berikut Informasi mengenai *Moisturizer ERHA 4...
# 51   Berikut Informasi mengenai *Erha 5 Evening Moi...
# 52   Berikut Informasi mengenai *Erha 6 Evening Moi...
# 54   Berikut Informasi mengenai *Erha 7 Foundation*...
# 55   Berikut Informasi mengenai *Erha 9 Foundation*...
# ..                                                 ...
# 546  _Black Carbon Skinprovement Laser_ adalah tind...
# 547  HISERHA Acne Guard Cream, merupakan krim pelem...
# 548  HISERHA Energy Bright Cream, merupakan krim pe...
# 549  ERHA PERFECT SHIELD URBAN SKIN DEFENSE Multi B...
# 550  ULTRACALM FACE SERUM - Kulit bebas gatal dan k...
#
# [448 rows x 3 columns]

# %%
df2['Content ID'].unique()
# Out:
# array(['product_info', 'treatment_info'], dtype=object)

# %%
df2['Version ID'] = df2['Version ID'].map(lambda x : str(x).lower())

# %%
question_pattern_list = []

for c, q in zip(df2['Content ID'], df2['Version ID']):
    question_pattern_list.append(model.create_questions(str(c), str(q).lower()))

df2['Question Pattern'] = question_pattern_list
df2
# Out:
#          Content ID                                         Version ID  \
# 50     product_info                                              erha4
# 51     product_info                                              erha5
# 52     product_info                                              erha6
# 54     product_info                                              erha7
# 55     product_info                                              erha9
# ..              ...                                                ...
# 546  treatment_info                   black carbon skinprovement laser
# 547    product_info                                   acne guard cream
# 548    product_info                        hiserha energy bright cream
# 549    product_info  urban skin defense multi benefit refreshing spray
# 550    product_info            erha skinsitive df ultracalm face serum
#
#                                               Answer 1  \
# 50   Berikut Informasi mengenai *Moisturizer ERHA 4...
# 51   Berikut Informasi mengenai *Erha 5 Evening Moi...
# 52   Berikut Informasi mengenai *Erha 6 Evening Moi...
# 54   Berikut Informasi mengenai *Erha 7 Foundation*...
# 55   Berikut Informasi mengenai *Erha 9 Foundation*...
# ..                                                 ...
# 546  _Black Carbon Skinprovement Laser_ adalah tind...
# 547  HISERHA Acne Guard Cream, merupakan krim pelem...
# 548  HISERHA Energy Bright Cream, merupakan krim pe...
# 549  ERHA PERFECT SHIELD URBAN SKIN DEFENSE Multi B...
# 550  ULTRACALM FACE SERUM - Kulit bebas gatal dan k...
#
#                                       Question Pattern
# 50   [erha4, kegunaan erha4, penggunaan erha4, cara...
# 51   [erha5, kegunaan erha5, penggunaan erha5, cara...
# 52   [erha6, kegunaan erha6, penggunaan erha6, cara...
# 54   [erha7, kegunaan erha7, penggunaan erha7, cara...
# 55   [erha9, kegunaan erha9, penggunaan erha9, cara...
# ..                                                 ...
# 546  [black carbon skinprovement laser, apa itu bla...
# 547  [acne guard cream, kegunaan acne guard cream, ...
# 548  [hiserha energy bright cream, kegunaan hiserha...
# 549  [urban skin defense multi benefit refreshing s...
# 550  [erha skinsitive df ultracalm face serum, kegu...
#
# [448 rows x 4 columns]

# %%
df2[df2['Version ID'] == 'paket anti aging home peeling \xe2\x80\x93 brightening home peeling solution']['Answer 1']
# Out:
# Series([], Name: Answer 1, dtype: object)

# %% [markdown]
# ## Creating JSON

# %%
def unit_transform(str):
    replacements = {
            '[0-9]+,' : '.',
        }

    for key, value in replacements.items():
        str = re.sub(key, value, str)
    return (str)

# %%
def generate_json(df):
    contexts = df['Question Pattern']
    tags = df['Version ID']
    responses = df['Answer 1']
    result = "{\"intents\": ["

    for context, tag, response in zip(contexts, tags, responses):
        result = result + "{\"context\": \"\",\"patterns\": " + str(context) + ",\"responses\": "+ "[\""+ str(response) +"\"]" +",\"tag\": \""+ str(tag) +"\"},"

    result = r"{}".format(result)
    result = result.replace("\'", "\"")
    result = result.replace("\'", "\"")
    # result = result.replace("“", r"\"")
    # result = result.replace("”", r"\"")
    # result = result.replace("–", r"-")

    return unit_transform(result) + "]}"

# %%
f = open("data.json", "w")
f.write(str(generate_json(df2).encode('ascii', 'replace')))
f.close()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [80], line 2
#       1 f = open("data.json", "w")
# ----> 2 f.write(str(generate_json(df2).encode('ascii', 'replace')))
#       3 f.close()
#
# Cell In [77], line 17, in generate_json(df)
#      12 result = result.replace("\'", "\"")
#      13 # result = result.replace("“", r"\"")
#      14 # result = result.replace("”", r"\"")
#      15 # result = result.replace("–", r"-")
# ---> 17 return unit_transform(result) + "]}"
#
# Cell In [76], line 7, in unit_transform(str)
#       2 replacements = {
#       3         '([0-9]+,' : '.',
#       4     }
#       6 for key, value in replacements.items():
# ----> 7     str = re.sub(key, value, str)
#       8 return (str)
#
# File E:\Apps\py\lib\re.py:209, in sub(pattern, repl, string, count, flags)
#     202 def sub(pattern, repl, string, count=0, flags=0):
#     203     """Return the string obtained by replacing the leftmost
#     204     non-overlapping occurrences of the pattern in string by the
#     205     replacement repl.  repl can be either a string or a callable;
#     206     if a string, backslash escapes in it are processed.  If it is
#     207     a callable, it's passed the Match object and must return
#     208     a replacement string to be used."""
# --> 209     return _compile(pattern, flags).sub(repl, string, count)
#
# File E:\Apps\py\lib\re.py:303, in _compile(pattern, flags)
#     301 if not sre_compile.isstring(pattern):
#     302     raise TypeError("first argument must be string or compiled pattern")
# --> 303 p = sre_compile.compile(pattern, flags)
#     304 if not (flags & DEBUG):
#     305     if len(_cache) >= _MAXCACHE:
#     306         # Drop the oldest item
#
# File E:\Apps\py\lib\sre_compile.py:788, in compile(p, flags)
#     786 if isstring(p):
#     787     pattern = p
# --> 788     p = sre_parse.parse(p, flags)
#     789 else:
#     790     pattern = None
#
# File E:\Apps\py\lib\sre_parse.py:955, in parse(str, flags, state)
#     952 state.str = str
#     954 try:
# --> 955     p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     956 except Verbose:
#     957     # the VERBOSE flag was switched on inside the pattern.  to be
#     958     # on the safe side, we'll parse the whole thing again...
#     959     state = State()
#
# File E:\Apps\py\lib\sre_parse.py:444, in _parse_sub(source, state, verbose, nested)
#     442 start = source.tell()
#     443 while True:
# --> 444     itemsappend(_parse(source, state, verbose, nested + 1,
#     445                        not nested and not items))
#     446     if not sourcematch("|"):
#     447         break
#
# File E:\Apps\py\lib\sre_parse.py:843, in _parse(source, state, verbose, nested, first)
#     841 p = _parse_sub(source, state, sub_verbose, nested + 1)
#     842 if not source.match(")"):
# --> 843     raise source.error("missing ), unterminated subpattern",
#     844                        source.tell() - start)
#     845 if group is not None:
#     846     state.closegroup(group, p)
#
# error: missing ), unterminated subpattern at position 0
